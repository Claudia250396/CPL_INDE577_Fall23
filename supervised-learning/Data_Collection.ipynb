# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')

variables= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Proyecto final/vi_kiur_5_2009plus_1.csv', encoding='latin')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/apple/Documents/Houston/Rice University/MEML/577_INDE Data Science&Machine Learning/CPL_INDE577_Fall23/supervised-learning/Data_Collection.ipynb Cell 1 line 6
#       <a href='vscode-notebook-cell:/Users/apple/Documents/Houston/Rice%20University/MEML/577_INDE%20Data%20Science%26Machine%20Learning/CPL_INDE577_Fall23/supervised-learning/Data_Collection.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> import seaborn as sns
#       <a href='vscode-notebook-cell:/Users/apple/Documents/Houston/Rice%20University/MEML/577_INDE%20Data%20Science%26Machine%20Learning/CPL_INDE577_Fall23/supervised-learning/Data_Collection.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> import matplotlib.pyplot as plt
# ...

# %%
crimen=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Proyecto final/crimen/vi_hpd_crime_CTA_nibrsCode_TabDelim.txt',sep='\t')
crimen

crimen=crimen[crimen['NULL'].isna()== False]
crimen
crimen.rename(columns={'NULL':'cta_code','NULL.1':'cta_name'}, inplace=True)
crimen
# Out:
#        2019 cta_code  cta_name  09A  Murder & Nonnegligent Manslaughter  A  \
# 42     2019     K001  Downtown  09A  Murder & Nonnegligent Manslaughter  A
# 43     2019     K001  Downtown  11A                       Forcible Rape  A
# 44     2019     K001  Downtown  11B                     Forcible Sodomy  A
# 45     2019     K001  Downtown  11D                   Forcible Fondling  A
# 46     2019     K001  Downtown  120                             Robbery  A
# ...     ...      ...       ...  ...                                 ... ..
# 13675  2021     K140   Baytown  90Z                  All Other Offenses  B
# 13676  2021     K143   Tomball  13B                      Simple Assault  A
# 13677  2021     K143   Tomball  23D                 Theft From Building  A
# 13678  2021     K143   Tomball  23H                   All Other Larceny  A
# 13679  2021     K143   Tomball  90Z                  All Other Offenses  B
#
#                              Person  14
# ...

# %%
crimen.rename(columns={'Murder & Nonnegligent Manslaughter':'crimes'}, inplace=True)
crimen
crimen=crimen[crimen['2019'].isin([2021])]
crimen.reset_index(inplace=True)
crimen
# Out:
#       index  2019 cta_code  cta_name  09A                              crimes  \
# 0      9405  2021     K001  Downtown  09A  Murder & Nonnegligent Manslaughter
# 1      9406  2021     K001  Downtown  100                Kidnapping/Abduction
# 2      9407  2021     K001  Downtown  11A                       Forcible Rape
# 3      9408  2021     K001  Downtown  11B                     Forcible Sodomy
# 4      9409  2021     K001  Downtown  11D                   Forcible Fondling
# ...     ...   ...      ...       ...  ...                                 ...
# 4270  13675  2021     K140   Baytown  90Z                  All Other Offenses
# 4271  13676  2021     K143   Tomball  13B                      Simple Assault
# 4272  13677  2021     K143   Tomball  23D                 Theft From Building
# 4273  13678  2021     K143   Tomball  23H                   All Other Larceny
# 4274  13679  2021     K143   Tomball  90Z                  All Other Offenses
#
# ...

# %%
crimen.drop(['index','09A','Person'], axis=1, inplace= True)
# Out:
# <ipython-input-5-fb9b6cdf9fe7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crimen.drop(['index','09A','Person'], axis=1, inplace= True)

# %%
crimen
# Out:
#       2019 cta_code  cta_name                              crimes  A  14
# 0     2021     K001  Downtown  Murder & Nonnegligent Manslaughter  A   2
# 1     2021     K001  Downtown                Kidnapping/Abduction  A   4
# 2     2021     K001  Downtown                       Forcible Rape  A  10
# 3     2021     K001  Downtown                     Forcible Sodomy  A  10
# 4     2021     K001  Downtown                   Forcible Fondling  A  12
# ...    ...      ...       ...                                 ... ..  ..
# 4270  2021     K140   Baytown                  All Other Offenses  B   1
# 4271  2021     K143   Tomball                      Simple Assault  A   1
# 4272  2021     K143   Tomball                 Theft From Building  A   1
# 4273  2021     K143   Tomball                   All Other Larceny  A   4
# 4274  2021     K143   Tomball                  All Other Offenses  B   1
#
# [4275 rows x 6 columns]

# %%
crimen.rename(columns={'crimes': 'Offense_Type', '14': 'Num_Offenses'}, inplace=True)
# Out:
# <ipython-input-7-09ef96e70706>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crimen.rename(columns={'crimes': 'Offense_Type', '14': 'Num_Offenses'}, inplace=True)

# %%
crimen
# Out:
#       2019 cta_code  cta_name                        Offense_Type  A  \
# 0     2021     K001  Downtown  Murder & Nonnegligent Manslaughter  A
# 1     2021     K001  Downtown                Kidnapping/Abduction  A
# 2     2021     K001  Downtown                       Forcible Rape  A
# 3     2021     K001  Downtown                     Forcible Sodomy  A
# 4     2021     K001  Downtown                   Forcible Fondling  A
# ...    ...      ...       ...                                 ... ..
# 4270  2021     K140   Baytown                  All Other Offenses  B
# 4271  2021     K143   Tomball                      Simple Assault  A
# 4272  2021     K143   Tomball                 Theft From Building  A
# 4273  2021     K143   Tomball                   All Other Larceny  A
# 4274  2021     K143   Tomball                  All Other Offenses  B
#
#       Num_Offenses
# 0                2
# 1                4
# 2               10
# 3               10
# 4               12
# ...

# %%
crimen_pt1=crimen.groupby(['cta_code','A']).count()['2019'].reset_index()
crimen_pt1

crimen_final=pd.pivot(crimen_pt1,'cta_code','A','2019')
crimen_final
# Out:
# <ipython-input-9-eff18698a834>:4: FutureWarning: In a future version of pandas all arguments of pivot except for the argument 'data' will be keyword-only.
#   crimen_final=pd.pivot(crimen_pt1,'cta_code','A','2019')
# A            A    B
# cta_code
# K001      40.0  9.0
# K002      39.0  8.0
# K003      36.0  7.0
# K004      34.0  7.0
# K005      33.0  6.0
# ...        ...  ...
# K137       6.0  1.0
# K138       2.0  2.0
# K139       9.0  2.0
# K140      11.0  2.0
# K143       3.0  1.0
#
# [134 rows x 2 columns]

# %%
crimen_2014=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Proyecto final/crimen/crimen 2016/Curated/HPD_Crime_2009_2017_v01.csv')
crimen_2014
# Out:
#                               Location_Desc Police_Beat Street_Type  RecordID  \
# 0                                       NaN       14D40          RD         1
# 1                                       NaN        7C20         NaN         2
# 2                                       NaN       13D40        PKWY         3
# 3                                       NaN       18F40          RD         4
# 4                      RESTAURANT/CAFETERIA       24C60        PKWY         5
# ...                                     ...         ...         ...       ...
# 1094202       MISC. BUSINESS (NON-SPECIFIC)        9C40          ST   1094203
# 1094203               APARTMENT PARKING LOT        9C40          RD   1094204
# 1094204                 SERVICE/GAS STATION        9C40          ST   1094205
# 1094205  ELECTRONICS STORE, ELECTRICAL SUP.        9C40          RD   1094206
# 1094206             HOTEL/MOTEL PARKING LOT         NaN         NaN   1094207
#
# ...

# %%
crimen_2014.columns
# Out:
# Index(['Location_Desc', 'Police_Beat', 'Street_Type', 'RecordID',
#        'Date_Reported', 'Offense_Type', 'Block_Range', 'Street_Prefix',
#        'Street_Name', 'Num_Offenses', 'Srce_YYMM', 'NGC', 'Match_addr', 'X',
#        'Y', 'GEOID10', 'GEOID00', 'Police_Division', 'CTA_ID', 'CTA_Name',
#        'Geocoded', 'Location_Code', 'Hour'],
#       dtype='object')

# %%
crimen_2014.drop(['Location_Desc','Police_Beat','Street_Type','RecordID',
                  'Date_Reported','Block_Range','Street_Prefix',
                  'Street_Name', 'Location_Code', 'Hour',
                  'Police_Division', 'NGC', 'Match_addr', 'GEOID10', 'GEOID00'], axis=1, inplace= True)

# %%
conteo_valores = crimen_2014['Offense_Type'].value_counts()
print(conteo_valores)
# Out:
# Theft                 600981
# Burglary              200450
# Auto Theft            109185
# Aggravated Assault     90075
# Robbery                83792
# Rape                    7622
# Murder                  2088
# 1                         14
# Name: Offense_Type, dtype: int64

# %%
def Condicion(crimen_2014):
    if crimen_2014 in ['Aggravated Assault','Rape', 'Murder' ]:
        return 'A'
    else:
        return 'B'

crimen_2014['A']=crimen_2014['Offense_Type'].apply(Condicion)

# %%
crimen_2014
# Out:
#         Offense_Type  Num_Offenses Srce_YYMM          X          Y CTA_ID  \
# 0           Burglary             1   2014_06 -95.333268  29.637514   K066
# 1              Theft             1   2014_06 -95.331799  29.800081   K004
# 2              Theft             1   2014_07 -95.516291  29.625560   K070
# 3            Robbery             1   2014_07 -95.514200  29.736820   K080
# 4           Burglary             1   2014_09 -95.195466  29.924672   K106
# ...              ...           ...       ...        ...        ...    ...
# 1094202     Burglary             1   2017_12 -95.208459  29.770717   K054
# 1094203        Theft             1   2017_12 -95.218625  29.780813   K054
# 1094204        Theft             1   2017_12 -95.290745  29.777468   K005
# 1094205      Robbery             1   2017_12 -95.215481  29.772798   K054
# 1094206        Theft             1   2017_12 -95.410353  29.690881   K019
#
#                              CTA_Name  Geocoded  A
# ...

# %%
crimen_2014.Srce_YYMM=crimen_2014.Srce_YYMM.apply(lambda cell: cell.split("_")[0])
crimen_final_14=crimen_2014.groupby(["Srce_YYMM", "CTA_ID", "Offense_Type","A"]).count()["Num_Offenses"].reset_index()

# %%
crimen_final_14.rename(columns={'CTA_ID': 'cta_code'}, inplace=True)

# %%
crimen.columns
# Out:
# Index(['2019', 'cta_code', 'cta_name', 'Offense_Type', 'A', 'Num_Offenses'], dtype='object')

# %%
crimen_final_14.columns
# Out:
# Index(['Srce_YYMM', 'cta_code', 'Offense_Type', 'A', 'Num_Offenses'], dtype='object')

# %%
crimen.rename(columns={'2019': 'Srce_YYMM'}, inplace=True)
crimen.loc[:,['Srce_YYMM', 'cta_code', 'Offense_Type', 'A', 'Num_Offenses']]
# Out:
# <ipython-input-27-7bd9700ad23d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crimen.rename(columns={'2019': 'Srce_YYMM'}, inplace=True)
#       Srce_YYMM cta_code                        Offense_Type  A  Num_Offenses
# 0          2021     K001  Murder & Nonnegligent Manslaughter  A             2
# 1          2021     K001                Kidnapping/Abduction  A             4
# 2          2021     K001                       Forcible Rape  A            10
# 3          2021     K001                     Forcible Sodomy  A            10
# 4          2021     K001                   Forcible Fondling  A            12
# ...         ...      ...                                 ... ..           ...
# 4270       2021     K140                  All Other Offenses  B             1
# ...

# %%
tabla_final=pd.concat([crimen_final_14, crimen])
tabla_final
# Out:
#      Srce_YYMM cta_code         Offense_Type  A  Num_Offenses cta_name
# 0         2009     K001   Aggravated Assault  A            65      NaN
# 1         2009     K001           Auto Theft  B           137      NaN
# 2         2009     K001             Burglary  B            48      NaN
# 3         2009     K001               Murder  A             2      NaN
# 4         2009     K001                 Rape  A             6      NaN
# ...        ...      ...                  ... ..           ...      ...
# 4270      2021     K140   All Other Offenses  B             1  Baytown
# 4271      2021     K143       Simple Assault  A             1  Tomball
# 4272      2021     K143  Theft From Building  A             1  Tomball
# 4273      2021     K143    All Other Larceny  A             4  Tomball
# 4274      2021     K143   All Other Offenses  B             1  Tomball
#
# [10891 rows x 6 columns]
